# %%
#PROJECT TITLE:Analysis of Top 1000 Companies Dataset

# %%
#I am analyzing the Top 1000 Companies dataset to understand patterns in company growth, industry distribution, and funding. The goal is to identify factors that influence company success and provide insights useful for investors and business analysts.
#The dataset contains 1000 rows and 23 columns, including company name, industry, funding, revenue, and location. It was obtained from an online dataset source (Kaggle/other source if applicable).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#We imported libraries for data analysis (pandas, numpy) and visualization (matplotlib, seaborn).

# %%
# Out:
#           company_name          url           city state        country  \
# 0               OpenAI   openai.com  San Francisco    CA  United States
# 1              Alchemy  alchemy.com  San Francisco    CA  United States
# 2             dbt Labs   getdbt.com   Philadelphia    PA  United States
# 3  Wasabi Technologies   wasabi.com         Boston    MA  United States
# 4              Whatnot  whatnot.com    Los Angeles    CA  United States
#
#    employees                                       linkedin_url  founded  \
# 0        655             http://www.linkedin.com/company/openai   2015.0
# 1        201         http://www.linkedin.com/company/alchemyinc      NaN
# 2        511            http://www.linkedin.com/company/dbtlabs   2016.0
# 3        355  http://www.linkedin.com/company/wasabitechnolo...   2017.0
# 4        551        http://www.linkedin.com/company/whatnot-inc   2019.0
#
#     Industry  GrowjoRanking  ...  \
# 0         AI              1  ...
# ...
